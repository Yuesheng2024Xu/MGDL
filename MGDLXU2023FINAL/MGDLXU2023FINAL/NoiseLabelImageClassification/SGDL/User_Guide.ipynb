# %% [markdown]
# # Guidance for classfication via MGDL (Section 7.2)
#
# ## Data descriptions
# We create a seperate file 'dataset.py' to generate data for MNIST and FashionMINST. Readers can dive in this file to see how the data are generated.

# %% [markdown]
# ## Training and testing models
# We create the seperate 'main_run.py' for training models. In this file, there are several parameters need to be setted. Readers can set different parameter to set the performance

# %%
import glob
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %run main_run.py
# Out:
# 2024-07-06 14:29:23.643414: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-06 14:29:23.818282: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/rfang002/envs/default-tensorflow-gpu-2.10.0/lib:/opt/conda/lib/libfabric:/usr/local/lib:/cm/shared/applications/slurm/23.11.3/lib:/cm/shared/applications/slurm/23.11.3/lib/slurm:/.singularity.d/libs
# 2024-07-06 14:29:23.818323: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %% [markdown]
# # Analysis results

# %%
from analysis import results_analysis
noise = 0.2
structure = 1
dataname = "MNIST"
#dataname = "FashionMNIST"

path = 'results/{}noise{}/structure{}/*.pickle'.format(dataname, noise, structure)

picklefile = []
for file in glob.glob(path):  
    print(file)
    picklefile.append(file) 

print(len(picklefile))
for file in picklefile:
    results_analysis(file, structure, noise)
# Out:
# results/MNISTnoise0.2/structure1/SGDL_noise0.2_batchzie128_epochs100_MAXLrate1.00e-03_MINLrate1.00e-04_TrA9.6052e-01_TeA8.1460e-01.pickle
# results/MNISTnoise0.2/structure1/SGDL_noise0.2_batchzie128_epochs5_MAXLrate1.00e-03_MINLrate1.00e-04_TrA7.8195e-01_TeA9.6540e-01.pickle
# 2
# results/MNISTnoise0.2/structure1/SGDL_noise0.2_batchzie128_epochs100_MAXLrate1.00e-03_MINLrate1.00e-04_TrA9.6052e-01_TeA8.1460e-01.pickle
# {'layers_dims': [784, 64, 128, 256, 128, 10], 'activation': 'relu', 'init_method': 'xavier'}
# {'optimizer': 'adam', 'beta1': 0.9, 'beta2': 0.999, 'epsilon': 1e-08, 'error': 1e-07, 'max_learning_rate': 0.001, 'min_learning_rate': 0.0001, 'epochs': 100, 'REC_FRQ': 1, 'SGD': True, 'mini_batch_size': 128}
# (tmax, tmin) = (0.001, 0.0001)
# train accuracy is 0.9605166666666667, validation accuracy is 0.8146
# SGDL training time is 497.08596301078796
# ...

# %%
# %run main_run.py
# Out:
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# results/MNISTnoise0.4/structure1/SGDL_noise0.4_batchzie128_epochs5_MAXLrate1.00e-03_MINLrate1.00e-04_TrA5.8740e-01_TeA9.5860e-01.pickle
