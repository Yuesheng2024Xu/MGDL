# %% [markdown]
# # Guidance for syhthetic data regression via MGDL (Section 7.1)

# %% [markdown]
# ## Data descriptions
# We create a seperate file 'data_generate.py' to generate data for example 1, 2, 3.  Readers can dive in this file to see how the data are generated.

# %% [markdown]
# ## Training and testing models
# We create the seperate 'main_run.py' for training models. In this file, there are several parameters need to be setted. Readers can set different parameter to set the performance

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %run main_run.py
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# ----------------------grade : 1---------------------
#
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
#
# ----------------------grade : 2---------------------
#
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
#
# ----------------------grade : 3---------------------
#
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------
# ------------------we use xavier initialize-------------------

# %% [markdown]
# ### showresults

# %%
import glob
from analysis import results_analysis

noise = 'False'
example = 'example1'

path = 'results/{}/noise{}/*.pickle'.format(example, noise) 
for file in glob.glob(path):
    results_analysis(file, True, example)
# Out:
# ################################################################################################################
# results/example1/noiseFalse/MGDL_xavier_noiseFalse_epoch[20, 20, 40]_minibatch32_MAXlearningrate1.0000e-01_MINlearningrate1.0000e-04_validation2.1183e-04_train1.0733e-05.pickle
# {'mul_layers_dims': [[1, 256, 256, 1], [256, 128, 128, 64, 1], [64, 64, 32, 32, 1]], 'activation': ['sin', 'relu', 'relu']}
# {'optimizer': 'adam', 'beta1': 0.9, 'beta2': 0.999, 'epsilon': 1e-08, 'error': 1e-07, 'SGD': True, 'mini_batch_size': 32, 'REC_FRQ': 1, 'init_method': 'xavier', 'MAX_learning_rate': [0.1, 0.01, 0.01], 'MIN_learning_rate': [0.0001, 0.0001, 0.0001], 'epochs': [20, 20, 40]}
# the train rse for each grade is [0.2912033425454208, 1.9101846769221024e-05, 1.0732836068520527e-05]
# the validation rse for each grade is [0.30446277680396305, 0.00022306324406509248, 0.00021183005893048886]
# the test rse for each grade is [0.29231216832000984, 1.5533192301851823e-05, 1.1191110025473861e-05]
# the train times for each grade is [11.850269794464111, 7.784138441085815, 4.411268711090088]
# the total train times is 24.045676946640015
